# %% [markdown]
# # Viewing STIS FUV Data
# ## 0. Collect the following data from the MAST Archive: odj102010
# Make sure to collect the calibrated data

# %% [markdown]
# ## 1. Import the necessary libraries:

# %%
# Import for: Reading in fits file
from astropy.table import Table
from astropy.io import fits

# Import for: Downloading necessary files. (Not necessary if you choose to collect data from MAST)
from astroquery.mast import Observations

# Import for: Plotting and specifying plotting parameters
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20,7)
plt.style.use("bmh")

# Import for: Quick Calculation and Data Analysis
import numpy as np

# %% [markdown]
# ## 2. Reading in the data

# %% [markdown]
# ### 2.1 Investigating the Data - Basics
# Before doing any operation on the data, we want to first explore the basics and data file structures.

# %% [markdown]
# The Aperture extracted, background subtracted, flux and wavelength calibrated spectra data is stored in fits file with suffix x1d. Open the x1d fits file and explore its info and header.

# %%
#first read the x1d fits file as a hdu list
x1d_file="./Data/FUV/obj102010/odj102010_x1d.fits"
x1d_hdul = fits.open(x1d_file)

# %%
#get information about the fits file
x1d_hdul.info()
# Out:
# Filename: ./Data/FUV/obj102010/odj102010_x1d.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     274   ()
#   1  SCI           1 BinTableHDU    156   1R x 19C   [1I, 1I, 1024D, 1024E, 1024E, 1024E, 1024E, 1024E, 1024E, 1024I, 1E, 1E, 1I, 1E, 1E, 1E, 1E, 1024E, 1E]

# %% [markdown]
# The primary header that stores keyword information describing the global properties of all of the exposures in the file

# %%
#get header of the fits file
x1d_header = fits.getheader(x1d_file,1)
x1d_header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                38946 / width of table in bytes
# NAXIS2  =                    1 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   19 / number of fields in each row
# TTYPE1  = 'SPORDER '           / label for field   1
# TFORM1  = '1I      '           / data format of field: 2-byte INTEGER
# TTYPE2  = 'NELEM   '           / label for field   2
# TFORM2  = '1I      '           / data format of field: 2-byte INTEGER
# TTYPE3  = 'WAVELENGTH'         / label for field   3
# TFORM3  = '1024D   '           / data format of field: 8-byte DOUBLE
# TUNIT3  = 'Angstroms'          / physical unit of field
# TTYPE4  = 'GROSS   '           / label for field   4
# TFORM4  = '1024E   '           / data format of field: 4-byte REAL
# TUNIT4  = 'Counts/s'           / physical unit of field
# TTYPE5  = 'BACKGROUND'         / label for field   5
# TFORM5  = '1024E   '           / data format of field: 4-byte REAL
# TUNIT5  = 'Counts/s'           / physical unit of field
# TTYPE6  = 'NET     '           / label for field   6
# TFORM6  = '1024E   '           / data format of field: 4-byte REAL
# TUNIT6  = 'Counts/s'           / physical unit of field
# TTYPE7  = 'FLUX    '           / label for field   7
# TFORM7  = '1024E   '           / data format of field: 4-byte REAL
# TUNIT7  = 'erg/s/cm**2/Angstrom' / physical unit of field
# TTYPE8  = 'ERROR   '           / label for field   8
# TFORM8  = '1024E   '           / data format of field: 4-byte REAL
# TUNIT8  = 'erg/s/cm**2/Angstrom' / physical unit of field
# TTYPE9  = 'NET_ERROR'          / label for field   9
# TFORM9  = '1024E   '           / data format of field: 4-byte REAL
# TUNIT9  = 'Counts/s'           / physical unit of field
# TTYPE10 = 'DQ      '           / label for field  10
# TFORM10 = '1024I   '           / data format of field: 2-byte INTEGER
# TTYPE11 = 'A2CENTER'           / label for field  11
# TFORM11 = '1E      '           / data format of field: 4-byte REAL
# TUNIT11 = 'pixel   '           / physical unit of field
# TTYPE12 = 'EXTRSIZE'           / label for field  12
# TFORM12 = '1E      '           / data format of field: 4-byte REAL
# TUNIT12 = 'pixel   '           / physical unit of field
# TTYPE13 = 'MAXSRCH '           / label for field  13
# TFORM13 = '1I      '           / data format of field: 2-byte INTEGER
# TUNIT13 = 'pixel   '           / physical unit of field
# TTYPE14 = 'BK1SIZE '           / label for field  14
# TFORM14 = '1E      '           / data format of field: 4-byte REAL
# TUNIT14 = 'pixel   '           / physical unit of field
# TTYPE15 = 'BK2SIZE '           / label for field  15
# TFORM15 = '1E      '           / data format of field: 4-byte REAL
# TUNIT15 = 'pixel   '           / physical unit of field
# TTYPE16 = 'BK1OFFST'           / label for field  16
# TFORM16 = '1E      '           / data format of field: 4-byte REAL
# TUNIT16 = 'pixel   '           / physical unit of field
# TTYPE17 = 'BK2OFFST'           / label for field  17
# TFORM17 = '1E      '           / data format of field: 4-byte REAL
# TUNIT17 = 'pixel   '           / physical unit of field
# TTYPE18 = 'EXTRLOCY'           / label for field  18
# TFORM18 = '1024E   '           / data format of field: 4-byte REAL
# TUNIT18 = 'pixel   '           / physical unit of field
# TTYPE19 = 'OFFSET  '           / label for field  19
# TFORM19 = '1E      '           / data format of field: 4-byte REAL
# TUNIT19 = 'pixel   '           / physical unit of field
# TDISP1  = 'I11     '           / display format for column
# TNULL1  =               -32767 / undefined value for column
# TDISP2  = 'I11     '           / display format for column
# TNULL2  =               -32767 / undefined value for column
# TDISP3  = 'G25.16  '           / display format for column
# TDISP4  = 'G15.7   '           / display format for column
# TDISP5  = 'G15.7   '           / display format for column
# TDISP6  = 'G15.7   '           / display format for column
# TDISP7  = 'G15.7   '           / display format for column
# TDISP8  = 'G15.7   '           / display format for column
# TDISP9  = 'G15.7   '           / display format for column
# TDISP10 = 'I11     '           / display format for column
# TNULL10 =               -32767 / undefined value for column
# TDISP11 = 'G15.7   '           / display format for column
# TDISP12 = 'G15.7   '           / display format for column
# TDISP13 = 'I11     '           / display format for column
# TNULL13 =               -32767 / undefined value for column
# TDISP14 = 'G15.7   '           / display format for column
# TDISP15 = 'G15.7   '           / display format for column
# TDISP16 = 'G15.7   '           / display format for column
# TDISP17 = 'G15.7   '           / display format for column
# TDISP18 = 'G15.7   '           / display format for column
# TDISP19 = 'G15.7   '           / display format for column
# INHERIT =                    T / inherit the primary header
# EXTNAME = 'SCI     '           / extension name
# EXTVER  =                    1 / extension version number
# ROOTNAME= 'odj102010'          / rootname of the observation set
# EXPNAME = 'odj102luq'          / exposure identifier
# ASN_MTYP= 'SCIENCE '           / Role of the Member in the Association
# WCSAXES =                    2 / number of World Coordinate System axes
# LTV1    =                   0. / offset in X to subsection start
# LTV2    =                   0. / offset in Y to subsection start
# LTM1_1  =                   1. / reciprocal of sampling rate in X
# LTM2_2  =                   1. / reciprocal of sampling rate in Y
# RA_APER =       319.6465078711 / RA of aperture reference position
# DEC_APER=       62.58580412301 / Declination of aperture reference position
# PA_APER =      -23.11314871521 / Position Angle of reference aperture center (de
# DISPAXIS=                    1 / dispersion axis; 1 = axis 1, 2 = axis 2, none
# SHIFTA1 =       -21.2476375591 / Spectrum shift in AXIS1 calculated from WAVECAL
# SHIFTA2 =      -12.02609965839 / Spectrum shift in AXIS2 calculated from WAVECAL
# ORIENTAT=             -22.7634 / position angle of image y axis (deg. e of n)
# SUNANGLE=            85.968559 / angle between sun and V1 axis
# MOONANGL=            92.673576 / angle between moon and V1 axis
# SUN_ALT =            -1.771215 / altitude of the sun above Earth's limb
# FGSLOCK = 'FINE    '           / commanded FGS lock (FINE,COARSE,GYROS,UNKNOWN)
# GYROMODE= 'T       '           / number of gyros scheduled, T=3+OBAD
# REFFRAME= 'ICRS    '           / guide star catalog version
# DATE-OBS= '2018-01-14'         / UT date of start of observation (yyyy-mm-dd)
# TIME-OBS= '08:31:01'           / UT time of start of observation (hh:mm:ss)
# EXPSTART=        58132.3548783 / exposure start time (Modified Julian Date)
# EXPEND  =       58132.36529496 / exposure end time (Modified Julian Date)
# EXPTIME =                 900. / exposure duration (seconds)--calculated
# EXPFLAG = 'NORMAL  '           / Exposure interruption indicator
# QUALCOM1= '        '
# QUALCOM2= '        '
# QUALCOM3= '        '
# QUALITY = '        '
# V_HELIO =     10.6959612503097 / heliocentric radial velocity (km/s)
# PATTSTEP=                    0 / position number of this point in the pattern
# NCOMBINE=                    1 / number of image sets combined during CR rejecti
# FILLCNT =                    0 / number of segments containing fill
# ERRCNT  =                    0 / number of segments containing errors
# PODPSFF =                    F / podps fill present (T/F)
# STDCFFF =                    F / science telemetry fill data present (T=1/F=0)
# STDCFFP = '0x5569  '           / science telemetry fill pattern (hex)
# OSWABSP =               880479 / Slit Wheel Absolute position
# OMSCYL1P=                 1589 / Mode select cylinder 1 position
# OMSCYL3P=                 4679 / Mode select cylinder 3 position
# OMSCYL4P=                 1685 / Mode select cylinder 4 position
# GLOBRATE=       3110.965555556 / global count rate
# GLOBLIM = 'NOT-EXCEEDED'       / was global linearity level exceeded?
# OM1CAT  =              39.1821 / (dgC) M1 charge amplifier temp
# OM2CAT  =              39.4263 / (dgC) M2 charge amplifier temp
# DOPPON  =                    F / on-board doppler correction enabled
# DOPPZERO=       58132.28913172 / Doppler shift zero phase time (MJD)
# DOPPMAG =                    0 / Doppler shift magnitude (hi-res pixels)
# DOPPER  =                5723. / Doppler shift period (seconds)
# ORBITPER=                5723. / Orbital Period used on board for Doppler corr.
# NGOODPIX=              1020980 / number of good pixels
# SDQFLAGS=                31743 / serious data quality flags
# GOODMIN =         -0.013770226 / minimum value of good pixels
# GOODMAX =            2077.7029 / maximum value of good pixels
# GOODMEAN=            2.7046466 / mean value of good pixels
# SNRMIN  =           -165.64568 / minimum signal to noise of good pixels
# SNRMAX  =            44.079891 / maximum signal to noise of good pixels
# SNRMEAN =           -126.13473 / mean value of signal to noise of good pixels
# SOFTERRS=                    0 / number of soft error pixels (DQF=1)
# MEANDARK=             0.005688 / average of the dark values subtracted
# SPORDER =                    1 / Spectral order
# DIFF2PT =                   1. / Diffuse to point source conversion factor
# CONT2EML=                   0. / Intensity conversion: continuum -> emission
# SCALE_A1=                   0. / Size of one pixel (arcsec) along dispersion axi
# OMEGAPIX=                   0. / Solid angle (arcsec**2) subtended by one pixel
# CRSCROFF=     351.886718802428 / offset from 1-D extraction cross-corr.

# %% [markdown]
# ### 2.2 Reading the x1d main data
# The main science data is stored at the first extension of the x1d fits file. We first read in the data as an astropy table.

# %%
#get data
x1d_data = Table.read(x1d_file,1)
# Out:
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]

# %%
# We can easily explore this astropy table
columns = x1d_data.colnames
# Print basic info about the table's columns
print("\nTable of FUV data with columns:\n", columns, "\n")
# Display a representation of the data table:
x1d_data
# Out:
# Table of FUV data with columns:
#  ['SPORDER', 'NELEM', 'WAVELENGTH', 'GROSS', 'BACKGROUND', 'NET', 'FLUX', 'ERROR', 'NET_ERROR', 'DQ', 'A2CENTER', 'EXTRSIZE', 'MAXSRCH', 'BK1SIZE', 'BK2SIZE', 'BK1OFFST', 'BK2OFFST', 'EXTRLOCY', 'OFFSET']
# <Table masked=True length=1>
#   SPORDER      NELEM    ...          EXTRLOCY [1024]                OFFSET
#                         ...                pix                       pix
#    int16       int16    ...              float32                   float32
# ----------- ----------- ... ---------------------------------- ---------------
#           1        1024 ...        382.2857 ..        397.2364        351.8867

# %% [markdown]
# ## 3. Plotting the data
# ### 3.1 Make a simple plot of the spectrum we just collected and read.

# %%
# From the astropy table, we first get all the data we need: wavelength, flux, and error
# notice that for astropy table, the column name is case sensitive
wl,flux,err=x1d_data[0]["WAVELENGTH","FLUX","ERROR"]

# %%
# make a plot of the data, use this cell to specify the format of the plot.
plt.plot(wl, flux, color="blue", label="FUV")
plt.legend(loc="best")
plt.title("STIS FUV Spectrum")
plt.xlabel("Wavelength [$\AA$]")
plt.ylabel("Flux [ergs/s/cm$^2$/$\AA$]")

# save the plot
plt.savefig("./Plots/FUV_Fig1.png")
plt.show()

# %% [markdown]
# ### 3.2 Make a more complex plot to examine the spectrum in detail.
# In this case, we segment the entire spectrum into 5 parts so that we can have a closer look at the flux of each wavelength.

# %%
for segment_row in x1d_data:  # Apply the following to each segment's data at a time
    # Selects all immediately useful data for the chosen segment
    wvln= segment_row["WAVELENGTH"]
    flux= segment_row["FLUX"]
    fluxErr = segment_row["ERROR"]
    minx, maxx = min(wvln), max(wvln)
    miny, maxy = min(flux), max(flux)
    rangex = maxx - minx
    fig = plt.figure(figsize=(14, 20))

    nRows = 5  # How many segments we wish to split the spectrum into

    for i in range(nRows):
        min_ = minx + i*rangex/nRows
        max_ = minx + (i+1)*rangex/nRows
        ax = plt.subplot(nRows, 1, i+1)

        if i == 0:  # A way to set Title, xlabel, and ylabel that will work independent of number of rows
            ax.set_title(
                f"Segment Spectrum split into segments", size=30)
        if i == nRows - 1:
            ax.set_xlabel("Wavelength [$\AA$]", size=30)
        if i == int(nRows/2):
            ax.set_ylabel(
                'Flux [$erg\ s^{-1}\ cm^{-2}\ Angstrom^{-1}$]', size=30)

        # Create the plot itself
        ax.errorbar(wvln, flux, fluxErr, c=plt.cm.rainbow((i+1)/nRows), alpha=0.8,
                    marker='.', markerfacecolor='k', markersize=2, mew=0)

        ax.set_xlim(min_, max_)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 4.Data Quality
# ### 4.1 Data Quality Frequencies Histogram
# Make a histogram according to the data quality flags, and label the bins by what each data quality values actually means.
# More info: https://hst-docs.stsci.edu/stisdhb/chapter-2-stis-data-structure/2-5-error-and-data-quality-array

# %%
#First get the data quality flag from the x1d fits file, and convert them to log2 values
#The data quality flag is a masked array that "hides" the pixels with no data quality issue. 
#We fill those "good points" with -1 in our case
log_DQ = np.log2(x1d_data[0]["DQ"]).filled(-1)
log_DQ = log_DQ.astype(int)
# Out:
# /Users/kding/miniconda3/envs/stis/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log2
#   after removing the cwd from sys.path.

# %%
#Assign the meaning of each data quality and make the histogram
meanings = ["No Anomalies","Reed-Solomon decoding","Lost Data","Bad Detector Pixel","Masked by Occulating Bar",
           "Dark Rate > 5 sigma * median dark level","Large Blemish","Vignetted Pixel","Overscan Region",
            "Saturated Pixel","Bad Pixel in Reference File","Small Blemish","Background Pixel Rejected",
           "Affected by Bad Input Data","Rejected during Image Combination","Not CTI Corrected"]
for i in range(len(meanings)):
    meanings[i] = str(int(2**(i-1)))+": "+meanings[i]

bins_ = np.arange(-1, 15)
plt.title("Data quality flag frequencies")
h = plt.hist(log_DQ,bins=bins_)
x = plt.xticks(bins_+0.5, labels=meanings, rotation='vertical', fontsize=15)

# %% [markdown]
# ### 4.2 Removing "Serious Data Quality"
# Through the calibaration pipeline, some data qualities are marked "serious". The value of serious data qualities are marked through "SDQFLAGS". We can decompose that value according to the bits in order to see the specific data quality flags that are marked serious.

# %%
sdqFlags_fuv=fits.getheader(x1d_file,1)["SDQFLAGS"]
sdq=[]
print(
    f"The FUV was processed with SDQFLAGS = {sdqFlags_fuv}, which in binary is {bin(sdqFlags_fuv)[2:]}")
print("\t\tThus, the following DQ-flagged data get weighted by 0:\n")
for i, char in enumerate(bin(sdqFlags_fuv)[2:]):
    if char == '1':
        if 2**(i+1) not in sdq:
            sdq.append(2**(i))
        print(f"\t\t\t", meanings[i+1])
# Out:
# The FUV was processed with SDQFLAGS = 31743, which in binary is 111101111111111
# 		Thus, the following DQ-flagged data get weighted by 0:
#
# 			 1: Reed-Solomon decoding
# 			 2: Lost Data
# 			 4: Bad Detector Pixel
# 			 8: Masked by Occulating Bar
# 			 32: Large Blemish
# 			 64: Vignetted Pixel
# 			 128: Overscan Region
# 			 256: Saturated Pixel
# 			 512: Bad Pixel in Reference File
# 			 1024: Small Blemish
# 			 2048: Background Pixel Rejected
# 			 4096: Affected by Bad Input Data
# 			 8192: Rejected during Image Combination
# 			 16384: Not CTI Corrected

# %%
# Filter the datapoints to where there are no serious DQ flags
mask_noSDQ = [not elem for elem in np.in1d(x1d_data[0]["DQ"], sdq)]
wvln_noSDQ, flux_noSDQ = x1d_data[0]["WAVELENGTH"][
    mask_noSDQ], x1d_data[0]["FLUX"][mask_noSDQ]

# Make the figure:
plt.figure(figsize=(10, 6))

# Plot the filtered datapoints
plt.plot(wvln_noSDQ, flux_noSDQ)

# Format the figure
plt.title("FUV without SDQ flagged data", size=20)
plt.xlabel('Wavelength [$\AA$]', size=20)
plt.ylabel('Flux [$erg\ s^{-1}\ cm^{-2}\ Angstrom^{-1}$]', size=15)
# Out:
# Text(0, 0.5, 'Flux [$erg\\ s^{-1}\\ cm^{-2}\\ Angstrom^{-1}$]')

# %% [markdown]
# ## 5. STIS FUV Image
# ### 5.1 Explore image file structure
# The rectified, wavelength and flux calibrated first order spectra or Geometrically corrected imaging data is stored in the fits file with the x2d extension. Similar to what we did to the x1d file, we first open the fits file to explore its file structure.

# %%
#read in the x2d file and get its info
x2d_file="./Data/FUV/obj102010/odj102010_x2d.fits"
fits.info(x2d_file)
# Out:
# Filename: ./Data/FUV/obj102010/odj102010_x2d.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     277   ()
#   1  SCI           1 ImageHDU       120   (1201, 1201)   float32
#   2  ERR           1 ImageHDU        61   (1201, 1201)   float32
#   3  DQ            1 ImageHDU        44   (1201, 1201)   int16

# %% [markdown]
# - The first, of extension type SCI, stores the science values.
# - The second, of extension type ERR, contains the statistical errors, which are propagated through the calibration process. It is unpopulated in raw data files.
# - The third, of extension type DQ, stores the data quality values, which flag suspect pixels in the corresponding SCI data. It is unpopulated in raw data files.

# %% [markdown]
# Similarly, we can also get the header from this fits file to see the scientific metadata.

# %%
#get header of the fits file
x2d_header = fits.getheader(x2d_file,0)
x2d_header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# ORIGIN  = 'HSTIO/CFITSIO March 2010' / FITS file originator
# DATE    = '2022-04-16' / date this file was written (yyyy-mm-dd)
# NEXTEND =                    3 / Number of standard extensions
# FILENAME= 'odj102010_x2d.fits' / name of file
# FILETYPE= 'SCI      '          / type of data found in data file
#
# TELESCOP= 'HST'                / telescope used to acquire data
# INSTRUME= 'STIS  '             / identifier for instrument used to acquire data
# EQUINOX =               2000.0 / equinox of celestial coord. system
#
#               / DATA DESCRIPTION KEYWORDS
#
# ROOTNAME= 'odj102010                         ' / rootname of the observation set
# PRIMESI = 'STIS  '             / instrument designated as prime
#
#               / TARGET INFORMATION
#
# TARGNAME= '-ALF-CEP                       ' / proposer's target name
# RA_TARG =   3.196465078711E+02 / right ascension of the target (deg) (J2000)
# DEC_TARG=   6.258580412301E+01 / declination of the target (deg) (J2000)
#
#               / PROPOSAL INFORMATION
#
# PROPOSID=                15168 / PEP proposal identifier
# LINENUM = '02.002         '    / proposal logsheet line number
# PR_INV_L= 'Grady                         ' / last name of principal investigator
# PR_INV_F= 'Carol               ' / first name of principal investigator
# PR_INV_M= 'A.                  ' / middle name / initial of principal investigat
#
#               / SUMMARY EXPOSURE INFORMATION
#
# TDATEOBS= '2018-01-14'         / UT date of start of first exposure in file
# TTIMEOBS= '08:31:01'           / UT start time of first exposure in file
# TEXPSTRT=   5.813235487830E+04 / start time (MJD) of 1st exposure in file
# TEXPEND =       58132.36529496 / end time (MJD) of last exposure in the file
# TEXPTIME=                 900. / total exposure time (seconds)
# QUALCOM1= '                                                                    '
# QUALCOM2= '                                                                    '
# QUALCOM3= '                                                                    '
# QUALITY = '                                                                    '
#
#               / TARGET OFFSETS (POSTARGS)
#
# POSTARG1=             0.000000 / POSTARG in axis 1 direction
# POSTARG2=             0.000000 / POSTARG in axis 2 direction
#
#               / DIAGNOSTIC KEYWORDS
#
# OVERFLOW=                    0 / Number of science data overflows
# PROCTIME=   5.968582344907E+04 / pipeline processing time (MJD)
# OPUS_VER= 'HSTDP 2022_1                ' / data processing software system versi
# AWSYSVER= 'v0.4.35 '           / cloud infrastructure package version
# AWSDPVER= 'v0.2.18 '           / cloud docker image version
# CSYS_VER= 'caldp_20220406'     / calibration software system version id
# CAL_VER = '3.4.2 (19-Jan-2018)' / CALSTIS code version
#
#               / SCIENCE INSTRUMENT CONFIGURATION
#
# CFSTATUS= 'SUPPORTED  '        / configuration status (support., avail., eng.)
# OBSTYPE = 'SPECTROSCOPIC '     / observation type - imaging or spectroscopic
# OBSMODE = 'ACCUM     '         / operating mode
# PHOTMODE= 'STIS 52X0.2 G140M FUVMAMA 1540 MJD#58132.3549' / obser
# SCLAMP  = 'NONE          '     / lamp status, NONE or name of lamp which is on
# LAMPSET = '0.0   '             / spectral cal lamp current value (milliamps)
# NRPTEXP =                    1 / number of repeat exposures in set: default 1
# SUBARRAY=                    F / data from a subarray (T) or full frame (F)
# DETECTOR= 'FUV-MAMA  '         / detector in use: NUV-MAMA, FUV-MAMA, or CCD
# OPT_ELEM= 'G140M   '           / optical element in use
# APERTURE= '52X0.2          '   / aperture name
# PROPAPER= '52X0.2          '   / proposed aperture name
# FILTER  = 'Clear             ' / filter in use
# APER_FOV= '52x0.2          '   / aperture field of view
# CENWAVE =                 1540 / central wavelength of spectrum
# REPELLER= 'ON '                / repeller voltage: applies only to fuv-mama
#
#               / MAMA OFFSETS
#
# MOFFSET1=                    0 / axis 1 MAMA offset (low-res pixels)
# MOFFSET2=                 -119 / axis 2 MAMA offset (low-res pixels)
#
#               / LOCAL RATE CHECK IMAGE
#
# LRC_XSTS=                    F / Local Rate check image exists (T/F)
# LRC_FAIL=                    F / Local Rate Check Failed (T/F)
#
#               / READOUT DEFINITION PARAMETERS
#
# CENTERA1=                  513 / subarray axis1 center pt in unbinned dect. pix
# CENTERA2=                  513 / subarray axis2 center pt in unbinned dect. pix
# SIZAXIS1=                 1024 / subarray axis1 size in unbinned detector pixels
# SIZAXIS2=                 1024 / subarray axis2 size in unbinned detector pixels
# BINAXIS1=                    1 / axis1 data bin size in unbinned detector pixels
# BINAXIS2=                    1 / axis2 data bin size in unbinned detector pixels
#
#               / CALIBRATION SWITCHES: PERFORM, OMIT, COMPLETE
#
# DQICORR = 'COMPLETE'           / data quality initialization
# RPTCORR = 'OMIT    '           / add individual repeat observations
# DOPPCORR= 'OMIT    '           / convolve ref. files with orbital Doppler shift
# LORSCORR= 'COMPLETE'           / Convert MAMA data to Lo-Res before processing
# GLINCORR= 'COMPLETE'           / correct for global detector non-linearities
# LFLGCORR= 'COMPLETE'           / flag pixels for local and global nonlinearities
# DARKCORR= 'COMPLETE'           / Subtract dark image
# FLATCORR= 'COMPLETE'           / flat field data
# STATFLAG=                    T / Calculate statistics?
# WAVECORR= 'COMPLETE'           / use wavecal to adjust wavelength zeropoint
# X1DCORR = 'PERFORM '           / Perform 1-D spectral extraction
# BACKCORR= 'PERFORM '           / subtract background (sky and interorder)
# HELCORR = 'COMPLETE'           / convert to heliocenttric wavelengths
# DISPCORR= 'COMPLETE'           / apply 2-dimensional dispersion solutions
# FLUXCORR= 'COMPLETE'           / convert to absolute flux units
# X2DCORR = 'COMPLETE'           / rectify 2-D spectral image
# SC2DCORR= 'OMIT    '           / 2-D scattered light correction algorithm
#
#               / CALIBRATION REFERENCE FILES
#
# BPIXTAB = 'oref$uce15153o_bpx.fits' / bad pixel table
# DARKFILE= 'oref$q591955ro_drk.fits' / dark image file name
# PFLTFILE= 'oref$mbj1658bo_pfl.fits' / pixel to pixel flat field file name
# LFLTFILE= 'oref$m1b2139no_lfl.fits' / low order flat
# PHOTTAB = 'oref$6471930po_pht.fits' / Photometric throughput table
# IMPHTTAB= 'oref$59l1632po_imp.fits' / Imaging photometric table
# APERTAB = 'oref$y2r1559to_apt.fits' / relative aperture throughput table
# MLINTAB = 'oref$j9r16559o_lin.fits' / MAMA linearity correction table
# WAVECAL = 'odj102010_wav.fits     ' / wavecal image file name
# APDESTAB= 'oref$16j16005o_apd.fits' / aperture description table
# SPTRCTAB= 'oref$q8l14504o_1dt.fits' / spectrum trace table
# DISPTAB = 'oref$m7p16110o_dsp.fits' / dispersion coefficient table
# INANGTAB= 'oref$h1v1541eo_iac.fits' / incidence angle correction table
# LAMPTAB = 'oref$l421050oo_lmp.fits' / template calibration lamp spectra table
# SDCTAB  = 'oref$16j1600ao_sdc.fits' / 2-D spatial distortion correction table
# XTRACTAB= 'oref$n7p10323o_1dx.fits' / parameters for 1-D spectral extraction tab
# PCTAB   = 'oref$y2r16005o_pct.fits' / Photometry correction table
# MOFFTAB = 'oref$h4s1350io_moc.fits' / MAMA offsets table
# WCPTAB  = 'oref$16j1600co_wcp.fits' / wavecal parameters table
# CDSTAB  = 'oref$k8m09584o_cds.fits' / Cross-Disperser Scattering table
# ECHSCTAB= 'oref$k8m09585o_ech.fits' / Echelle Scattering table
# EXSTAB  = 'oref$k8m09586o_exs.fits' / Echelle Cross-Dispersion Scattering table
# RIPTAB  = 'oref$6471930to_rip.fits' / Echelle Ripple table
# HALOTAB = 'oref$k8m09587o_hal.fits' / Detector Halo table
# TELTAB  = 'oref$k8m0958ao_tel.fits' / Telescope Point Spread Function table
# SRWTAB  = 'oref$k8m09589o_srw.fits' / Scattering Reference Wavelengths table
# TDSTAB  = 'oref$3ah1528co_tds.fits' / time-dependent sensitivity algorithm used
# TDCTAB  = 'N/A                    ' / Coefficient table for NUV MAMA dark scalin
# GACTAB  = 'N/A     '           / grating-aperture correction table
#
#               / TARGET ACQUISITION DATASET IDENTIFIERS
#
# ACQNAME = 'odj102LS% '         / rootname of acquisition exposure
# ACQTYPE = '               '    / type of acquisition
# PEAKNAM1= '          '         / rootname of 1st peakup exposure
# PEAKNAM2= '          '         / rootname of 2nd peakup exposure
#
#               / OTFR KEYWORDS
#
# T_SGSTAR= '                  ' / OMS calculated guide star control
#
#               / PATTERN KEYWORDS
#
# PATTERN1= 'NONE                    ' / primary pattern type
# P1_SHAPE= '                  ' / primary pattern shape
# P1_PURPS= '          '         / primary pattern purpose
# P1_NPTS =                    0 / number of points in primary pattern
# P1_PSPAC=             0.000000 / point spacing for primary pattern (arc-sec)
# P1_LSPAC=             0.000000 / line spacing for primary pattern (arc-sec)
# P1_ANGLE=             0.000000 / angle between sides of parallelogram patt (deg)
# P1_FRAME= '         '          / coordinate frame of primary pattern
# P1_ORINT=             0.000000 / orientation of pattern to coordinate frame (deg
# P1_CENTR= '   '                / center pattern relative to pointing (yes/no)
#
#               / ARCHIVE SEARCH KEYWORDS
#
# BANDWID =                 56.0 / bandwidth of the data
# SPECRES =              15400.0 / approx. resolving power at central wavelength
# CENTRWV =               1540.0 / central wavelength of the data
# MINWAVE =               1512.0 / minimum wavelength in spectrum
# MAXWAVE =               1568.0 / maximum wavelength in spectrum
# PLATESC =        2.9299969E-02 / plate scale (arcsec/pixel)
#
#               / PAPER PRODUCT SUPPORT KEYWORDS
#
# PROPTTL1= 'The Nature of the Star-Grazing Bodies in a System at the Age of the '
# PROPTTL2= 'Late Heavy Bombardment                                              '
# OBSET_ID= '02'                 / observation set id
# TARDESCR= 'STAR;A4-A9 V-IV;CORONA                                              '
# MTFLAG  = ' '                  / moving target flag; T if it is a moving target
# PARALLAX=   6.650000000000E-02 / target parallax from proposal
# MU_RA   =   1.505500000000E-01 / target proper motion from proposal (degrees RA)
# MU_DEC  =   4.909000000000E-02 / target proper motion from proposal (deg. DEC)
# MU_EPOCH= 'J2000.0   '         / epoch of proper motion from proposal
#
#               / ASSOCIATION KEYWORDS
#
# ASN_ID  = 'ODJ102010 '         / unique identifier assigned to association
# ASN_TAB = 'odj102010_asn.fits     ' / name of the association table
#
#               / POINTING INFORMATION
#
# PA_V3   =           202.085297 / position angle of V3-axis of HST (deg)
# CRDS_CTX= 'hst_1006.pmap'
# CRDS_VER= '11.9.0, b11.4.0, 64d96076d89b32a5687a6b77bb910ab93b3a99b3'
# BIASFILE= 'N/A     '
# CCDTAB  = 'N/A     '
# CRREJTAB= 'N/A     '
# IDCTAB  = 'N/A     '
# HISTORY DQICORR complete ...
# HISTORY   values checked for saturation
# HISTORY   DQ array initialized ...
# HISTORY   reference table oref$uce15153o_bpx.fits
# HISTORY     GROUND
# HISTORY     New BPIXTAB with opt_elem column and correct repeller wire flag----
# HISTORY Uncertainty array initialized.
# HISTORY LORSCORR complete; image converted from high-res to low-res.
# HISTORY GLINCORR complete ...
# HISTORY LFLGCORR complete ...
# HISTORY   reference table oref$j9r16559o_lin.fits
# HISTORY     GROUND
# HISTORY     T. Danks gathered Info
# HISTORY     T. Danks Gathered Info
# HISTORY DARKCORR complete ...
# HISTORY   reference image oref$q591955ro_drk.fits
# HISTORY     INFLIGHT 29/01/2003 03/08/2004
# HISTORY     Avg of 152 1380s darks from 9615 10034
# HISTORY FLATCORR complete ...
# HISTORY   reference image oref$mbj1658bo_pfl.fits
# HISTORY     INFLIGHT 17/03/1998 17/05/2002
# HISTORY     On-orbit FUV P-flat created from proposals 7645,8428,8862,8922
# HISTORY   reference image oref$m1b2139no_lfl.fits
# HISTORY     DUMMY
# HISTORY     Dummy file created by M. Mcgrath. Modified by C Proffitt
# HISTORY WAVECORR complete ...
# HISTORY   wavecal = odj102010_w2d_tmp.fits
# HISTORY X2DCORR complete ...
# HISTORY   reference table oref$16j1600ao_sdc.fits
# HISTORY     INFLIGHT 13/07/1997 13/06/2017
# HISTORY     Co-aligned fiducial bars via an update to the CDELT2 plate scales.-
# HISTORY     updated CDELT2 with inflight data, others Lindler-prelaunch
# HISTORY   reference table oref$16j16005o_apd.fits
# HISTORY     INFLIGHT 01/03/1997 13/06/2017
# HISTORY     Aligned long-slit bar positions for single-bar cases.--------------
# HISTORY     Microscope Meas./Hartig Post-launch Offsets
# HISTORY   reference table oref$m7p16110o_dsp.fits
# HISTORY     INFLIGHT 17/10/1997 17/10/1997
# HISTORY     Dispersion coefficients reference table
# HISTORY     INFLIGHT Cal. Disp. Coeffs
# HISTORY   reference table oref$h1v1541eo_iac.fits
# HISTORY     GROUND
# HISTORY     Prelaunch Calibration/Lindler and Models
# HISTORY     Model
# HISTORY   reference table oref$q8l14504o_1dt.fits
# HISTORY     GROUND
# HISTORY     New G140L traces and updated Echelle A2CENTER values
# HISTORY     Prelaunch calibration, Lindler/Hill
# HISTORY HELCORR complete
# HISTORY FLUXCORR complete ...
# HISTORY   reference table oref$6471930po_pht.fits
# HISTORY     INFLIGHT 27/02/1997 14/04/1998
# HISTORY     Updated sensitivity curves for G140L and E140M
# HISTORY     Bostroem Sensitivity of 01-Nov-2011
# HISTORY   reference table oref$y2r1559to_apt.fits
# HISTORY     MODEL
# HISTORY     Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# HISTORY     Bohlin/Hartig TIM Models Nov. 1998
# HISTORY   reference table oref$y2r16005o_pct.fits
# HISTORY     INFLIGHT 18/5/1997 19/12/1998
# HISTORY     Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# HISTORY      2 STIS observations averaged
# HISTORY   reference table oref$3ah1528co_tds.fits
# HISTORY     INFLIGHT 01/04/1997 04/07/2019
# HISTORY     Updated time and temperature sensitivities for all optical elements.
# HISTORY Statistics computed

# %% [markdown]
# ### 5.2 Show the image
# Now we collect the science image data from the fits file and show the image.

# %%
#get data and plot image
x2d_data=fits.open(x2d_file)[1].data
# show the image
# We normalize the color of each pixel to a specific range through vmin and vmax. 
# This value typically matches the magnitude of the x2d data, but can be changed to get better imaging result
plt.imshow(x2d_data,origin='lower',vmin=0,vmax=1e-13,cmap="viridis")
